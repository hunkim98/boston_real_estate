# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio

# %%
data_folder = "data/2019"

file_name = "geocoded_enriched_merged_sales.csv"

data_path = f"{data_folder}/{file_name}"

data = pd.read_csv(data_path)



data[data["full_address"].isna()]


# check which do not have full_address
# Out:
#        unit      street_name  sale_date        parcel       category  \
# 15       ST         Maverick   3/1/2019  01-05327-000  single_family
# 1965      1        Hanson ST  6/28/2019  03-05900-008          condo
# 2264      2      Chandler ST  7/17/2019  04-00050-004          condo
# 2438      3       Holyoke ST  1/16/2019  04-00741-006          condo
# 2439      4       Holyoke ST   7/9/2019  04-00741-008          condo
# 2471      3    St Botolph ST  8/13/2019  04-01007-006          condo
# 2601      2        BEACON ST   9/3/2019  05-02588-008          condo
# 2803      1  COMMONWEALTH AV   6/7/2019  05-03577-002          condo
# 2804      2  COMMONWEALTH AV   6/7/2019  05-03577-004          condo
# 2805      3  COMMONWEALTH AV   6/7/2019  05-03577-006          condo
# 2806      4  COMMONWEALTH AV   6/7/2019  05-03577-008          condo
# 2807      5  COMMONWEALTH AV   6/7/2019  05-03577-010          condo
# 2808      6  COMMONWEALTH AV   6/7/2019  05-03577-012          condo
# 2809      7  COMMONWEALTH AV   6/7/2019  05-03577-014          condo
# 2815      6  COMMONWEALTH AV  2/13/2019  05-03588-012          condo
# 2823      2  COMMONWEALTH AV   3/6/2019  05-03820-004          condo
# 3700  169-1             O ST  5/22/2019  07-02690-002          condo
# 3701  169-2             O ST   6/3/2019  07-02690-004          condo
# 3951   2597    Washington ST  10/4/2019  09-03742-202          condo
# 3977      1       CALUMET ST  9/18/2019  10-01167-002          condo
# 5036      1        PRINCE ST  9/26/2019  19-01610-002          condo
# 5780     ST            PLAIN  9/13/2019  16-03581-000     two_family
# 5913     ST         LAGRANGE  9/26/2019  20-02618-000     two_family
#
#      sale_price  street_no price_per_sf living_area  total_room_num  ...  \
# 15      625,000        233       545.95       1,145             NaN  ...
# 1965    570,000         38      1151.52         495             NaN  ...
# 2264    799,900        108      1164.34         687             NaN  ...
# 2438    900,000         24      1187.34         758             NaN  ...
# 2439  1,000,000         24      1129.94         885             NaN  ...
# 2471  1,900,000         41      1309.44       1,451             NaN  ...
# 2601  2,800,000        146      1637.43       1,710             NaN  ...
# 2803  3,183,622        315      1103.51       2,885             NaN  ...
# 2804    858,941        315      1201.32         715             NaN  ...
# 2805    727,496        315      1110.68         655             NaN  ...
# 2806    868,862        315      1206.75         720             NaN  ...
# 2807    758,084        315      1226.67         618             NaN  ...
# 2808    990,387        315      1284.88         771             NaN  ...
# 2809    657,227        315      1143.00         575             NaN  ...
# 2815  1,350,000        341       924.66       1,460             NaN  ...
# 2823    867,910        377       818.78       1,060             NaN  ...
# 3700  1,700,000        169       700.74       2,426             NaN  ...
# 3701  1,300,000        169       697.80       1,863             NaN  ...
# 3951    390,000       2597       305.40       1,277             NaN  ...
# 3977    550,000        148       511.63       1,075             NaN  ...
# 5036    780,000         48       576.50       1,353             NaN  ...
# 5780          9         12        2,383      25,000             NaN  ...
# 5913          7         84        2,788      75,000             NaN  ...
#
#       parking_spots  year_built  exterior_condition  foundation  full_address  \
# 15              NaN         NaN                 NaN         NaN           NaN
# 1965            NaN         NaN                 NaN         NaN           NaN
# 2264            NaN         NaN                 NaN         NaN           NaN
# 2438            NaN         NaN                 NaN         NaN           NaN
# 2439            NaN         NaN                 NaN         NaN           NaN
# 2471            NaN         NaN                 NaN         NaN           NaN
# 2601            NaN         NaN                 NaN         NaN           NaN
# 2803            NaN         NaN                 NaN         NaN           NaN
# 2804            NaN         NaN                 NaN         NaN           NaN
# 2805            NaN         NaN                 NaN         NaN           NaN
# 2806            NaN         NaN                 NaN         NaN           NaN
# 2807            NaN         NaN                 NaN         NaN           NaN
# 2808            NaN         NaN                 NaN         NaN           NaN
# 2809            NaN         NaN                 NaN         NaN           NaN
# 2815            NaN         NaN                 NaN         NaN           NaN
# 2823            NaN         NaN                 NaN         NaN           NaN
# 3700            NaN         NaN                 NaN         NaN           NaN
# 3701            NaN         NaN                 NaN         NaN           NaN
# 3951            NaN         NaN                 NaN         NaN           NaN
# 3977            NaN         NaN                 NaN         NaN           NaN
# 5036            NaN         NaN                 NaN         NaN           NaN
# 5780            NaN         NaN                 NaN         NaN           NaN
# 5913            NaN         NaN                 NaN         NaN           NaN
#
#      owner_name owner_property_count   x   y properties
# 15          NaN                  NaN NaN NaN        NaN
# 1965        NaN                  NaN NaN NaN        NaN
# 2264        NaN                  NaN NaN NaN        NaN
# 2438        NaN                  NaN NaN NaN        NaN
# 2439        NaN                  NaN NaN NaN        NaN
# 2471        NaN                  NaN NaN NaN        NaN
# 2601        NaN                  NaN NaN NaN        NaN
# 2803        NaN                  NaN NaN NaN        NaN
# 2804        NaN                  NaN NaN NaN        NaN
# 2805        NaN                  NaN NaN NaN        NaN
# 2806        NaN                  NaN NaN NaN        NaN
# 2807        NaN                  NaN NaN NaN        NaN
# 2808        NaN                  NaN NaN NaN        NaN
# 2809        NaN                  NaN NaN NaN        NaN
# 2815        NaN                  NaN NaN NaN        NaN
# 2823        NaN                  NaN NaN NaN        NaN
# 3700        NaN                  NaN NaN NaN        NaN
# 3701        NaN                  NaN NaN NaN        NaN
# 3951        NaN                  NaN NaN NaN        NaN
# 3977        NaN                  NaN NaN NaN        NaN
# 5036        NaN                  NaN NaN NaN        NaN
# 5780        NaN                  NaN NaN NaN        NaN
# 5913        NaN                  NaN NaN NaN        NaN
#
# [23 rows x 28 columns]

# %%
# for rows that have full_address na we create the full address manually
for index, row in data[data["full_address"].isna()].iterrows():
    data.loc[index, "full_address"] = f"{row['street_name']} {row['street_no']} Boston MA"
    
data[data["x"].isna() | data["y"].isna()]
# Out:
#        unit      street_name   sale_date        parcel       category  \
# 15       ST         Maverick    3/1/2019  01-05327-000  single_family
# 1965      1        Hanson ST   6/28/2019  03-05900-008          condo
# 2264      2      Chandler ST   7/17/2019  04-00050-004          condo
# 2384   4303        Dalton ST   9/12/2019  04-01149-240          condo
# 2438      3       Holyoke ST   1/16/2019  04-00741-006          condo
# 2439      4       Holyoke ST    7/9/2019  04-00741-008          condo
# 2471      3    St Botolph ST   8/13/2019  04-01007-006          condo
# 2601      2        BEACON ST    9/3/2019  05-02588-008          condo
# 2766    521  COMMONWEALTH AV  10/11/2019  05-01383-214          condo
# 2803      1  COMMONWEALTH AV    6/7/2019  05-03577-002          condo
# 2804      2  COMMONWEALTH AV    6/7/2019  05-03577-004          condo
# 2805      3  COMMONWEALTH AV    6/7/2019  05-03577-006          condo
# 2806      4  COMMONWEALTH AV    6/7/2019  05-03577-008          condo
# 2807      5  COMMONWEALTH AV    6/7/2019  05-03577-010          condo
# 2808      6  COMMONWEALTH AV    6/7/2019  05-03577-012          condo
# 2809      7  COMMONWEALTH AV    6/7/2019  05-03577-014          condo
# 2815      6  COMMONWEALTH AV   2/13/2019  05-03588-012          condo
# 2823      2  COMMONWEALTH AV    3/6/2019  05-03820-004          condo
# 3228    102      E FOURTH ST   10/1/2019  06-02076-014          condo
# 3390    708       SEAPORT BL  12/31/2019  06-02642-130          condo
# 3700  169-1             O ST   5/22/2019  07-02690-002          condo
# 3701  169-2             O ST    6/3/2019  07-02690-004          condo
# 3951   2597    Washington ST   10/4/2019  09-03742-202          condo
# 3977      1       CALUMET ST   9/18/2019  10-01167-002          condo
# 4050      2      ATHERTON ST    5/2/2019  11-01215-004          condo
# 4394      3        Seaver ST   3/28/2019  14-00992-006          condo
# 4953      2     GOLDSMITH ST   6/14/2019  19-01427-004          condo
# 5036      1        PRINCE ST   9/26/2019  19-01610-002          condo
# 5085      3     WACHUSETT ST   7/19/2019  19-04694-006          condo
# 5283      3    WASHINGTON ST   7/30/2019  20-10800-006          condo
# 5780     ST            PLAIN   9/13/2019  16-03581-000     two_family
# 5913     ST         LAGRANGE   9/26/2019  20-02618-000     two_family
#
#      sale_price  street_no price_per_sf living_area  total_room_num  ...  \
# 15      625,000        233       545.95       1,145             NaN  ...
# 1965    570,000         38      1151.52         495             NaN  ...
# 2264    799,900        108      1164.34         687             NaN  ...
# 2384  6,583,000          1      2955.99       2,227             4.0  ...
# 2438    900,000         24      1187.34         758             NaN  ...
# 2439  1,000,000         24      1129.94         885             NaN  ...
# 2471  1,900,000         41      1309.44       1,451             NaN  ...
# 2601  2,800,000        146      1637.43       1,710             NaN  ...
# 2766    699,500        160       997.86         701             3.0  ...
# 2803  3,183,622        315      1103.51       2,885             NaN  ...
# 2804    858,941        315      1201.32         715             NaN  ...
# 2805    727,496        315      1110.68         655             NaN  ...
# 2806    868,862        315      1206.75         720             NaN  ...
# 2807    758,084        315      1226.67         618             NaN  ...
# 2808    990,387        315      1284.88         771             NaN  ...
# 2809    657,227        315      1143.00         575             NaN  ...
# 2815  1,350,000        341       924.66       1,460             NaN  ...
# 2823    867,910        377       818.78       1,060             NaN  ...
# 3228    800,000        616       933.49         857             4.0  ...
# 3390  2,395,000        133      1603.08       1,494             5.0  ...
# 3700  1,700,000        169       700.74       2,426             NaN  ...
# 3701  1,300,000        169       697.80       1,863             NaN  ...
# 3951    390,000       2597       305.40       1,277             NaN  ...
# 3977    550,000        148       511.63       1,075             NaN  ...
# 4050    480,000         87       353.72       1,357             5.0  ...
# 4394    350,000        408       175.18       1,998             5.0  ...
# 4953    605,000         29       664.11         911             5.0  ...
# 5036    780,000         48       576.50       1,353             NaN  ...
# 5085    515,000         21       531.48         969             6.0  ...
# 5283    348,000       5259       316.08       1,101             5.0  ...
# 5780          9         12        2,383      25,000             NaN  ...
# 5913          7         84        2,788      75,000             NaN  ...
#
#       parking_spots  year_built  exterior_condition  foundation  \
# 15              NaN         NaN                 NaN         NaN
# 1965            NaN         NaN                 NaN         NaN
# 2264            NaN         NaN                 NaN         NaN
# 2384            0.0        2015           Excellent    Concrete
# 2438            NaN         NaN                 NaN         NaN
# 2439            NaN         NaN                 NaN         NaN
# 2471            NaN         NaN                 NaN         NaN
# 2601            NaN         NaN                 NaN         NaN
# 2766            0.0        1871                Good       Stone
# 2803            NaN         NaN                 NaN         NaN
# 2804            NaN         NaN                 NaN         NaN
# 2805            NaN         NaN                 NaN         NaN
# 2806            NaN         NaN                 NaN         NaN
# 2807            NaN         NaN                 NaN         NaN
# 2808            NaN         NaN                 NaN         NaN
# 2809            NaN         NaN                 NaN         NaN
# 2815            NaN         NaN                 NaN         NaN
# 2823            NaN         NaN                 NaN         NaN
# 3228            2.0        1900                Good       Stone
# 3390            2.0        2018           Excellent    Concrete
# 3700            NaN         NaN                 NaN         NaN
# 3701            NaN         NaN                 NaN         NaN
# 3951            NaN         NaN                 NaN         NaN
# 3977            NaN         NaN                 NaN         NaN
# 4050            0.0        1900             Average       Stone
# 4394            0.0        1905             Average       Stone
# 4953            1.0        1900             Average       Stone
# 5036            NaN         NaN                 NaN         NaN
# 5085            0.0        1900                Good       Stone
# 5283            1.0        1988                Good       Stone
# 5780            NaN         NaN                 NaN         NaN
# 5913            NaN         NaN                 NaN         NaN
#
#                                     full_address  \
# 15                        Maverick 233 Boston MA
# 1965                      Hanson ST 38 Boston MA
# 2264                   Chandler ST 108 Boston MA
# 2384         1  DALTON ST # 4303 BOSTON MA 02115
# 2438                     Holyoke ST 24 Boston MA
# 2439                     Holyoke ST 24 Boston MA
# 2471                  St Botolph ST 41 Boston MA
# 2601                     BEACON ST 146 Boston MA
# 2766  160  COMMONWEALTH AV # 521 BOSTON MA 02116
# 2803               COMMONWEALTH AV 315 Boston MA
# 2804               COMMONWEALTH AV 315 Boston MA
# 2805               COMMONWEALTH AV 315 Boston MA
# 2806               COMMONWEALTH AV 315 Boston MA
# 2807               COMMONWEALTH AV 315 Boston MA
# 2808               COMMONWEALTH AV 315 Boston MA
# 2809               COMMONWEALTH AV 315 Boston MA
# 2815               COMMONWEALTH AV 341 Boston MA
# 2823               COMMONWEALTH AV 377 Boston MA
# 3228      616  E FOURTH ST # 102 BOSTON MA 02127
# 3390     133  SEAPORT BLVD # 708 BOSTON MA 02210
# 3700                          O ST 169 Boston MA
# 3701                          O ST 169 Boston MA
# 3951                Washington ST 2597 Boston MA
# 3977                    CALUMET ST 148 Boston MA
# 4050         87  ATHERTON ST # 2 BOSTON MA 02130
# 4394          408  SEAVER ST # 3 BOSTON MA 02121
# 4953        29  GOLDSMITH ST # 2 BOSTON MA 02130
# 5036                      PRINCE ST 48 Boston MA
# 5085        21  WACHUSETT ST # 3 BOSTON MA 02130
# 5283     5259  WASHINGTON ST # 3 BOSTON MA 02132
# 5780                          PLAIN 12 Boston MA
# 5913                       LAGRANGE 84 Boston MA
#
#                                              owner_name owner_property_count  \
# 15                                                  NaN                  NaN
# 1965                                                NaN                  NaN
# 2264                                                NaN                  NaN
# 2384  LINCOLN KINNICUTT IRREVOCABLE CHILDREN'S TRUST...                  NaN
# 2438                                                NaN                  NaN
# 2439                                                NaN                  NaN
# 2471                                                NaN                  NaN
# 2601                                                NaN                  NaN
# 2766                       ELIZABETH O'NEILL TRUST 2024                  NaN
# 2803                                                NaN                  NaN
# 2804                                                NaN                  NaN
# 2805                                                NaN                  NaN
# 2806                                                NaN                  NaN
# 2807                                                NaN                  NaN
# 2808                                                NaN                  NaN
# 2809                                                NaN                  NaN
# 2815                                                NaN                  NaN
# 2823                                                NaN                  NaN
# 3228                     CATHERINE D'AMATO LIVING TRUST                  NaN
# 3390                                 BENTLEY JA'WHAUN L                  NaN
# 3700                                                NaN                  NaN
# 3701                                                NaN                  NaN
# 3951                                                NaN                  NaN
# 3977                                                NaN                  NaN
# 4050                     D'SOUZA FAMILY REVOCABLE TRUST                  NaN
# 4394                                   VENA'S DREAM LLC                  NaN
# 4953                               WEBER HANANE M'HAMDI                  NaN
# 5036                                                NaN                  NaN
# 5085                                 L'HEUREUX LAUREN E                  NaN
# 5283                   JOSEPH O'FARRELL REVOCABLE TRUST                  NaN
# 5780                                                NaN                  NaN
# 5913                                                NaN                  NaN
#
#        x   y properties
# 15   NaN NaN        NaN
# 1965 NaN NaN        NaN
# 2264 NaN NaN        NaN
# 2384 NaN NaN        NaN
# 2438 NaN NaN        NaN
# 2439 NaN NaN        NaN
# 2471 NaN NaN        NaN
# 2601 NaN NaN        NaN
# 2766 NaN NaN        NaN
# 2803 NaN NaN        NaN
# 2804 NaN NaN        NaN
# 2805 NaN NaN        NaN
# 2806 NaN NaN        NaN
# 2807 NaN NaN        NaN
# 2808 NaN NaN        NaN
# 2809 NaN NaN        NaN
# 2815 NaN NaN        NaN
# 2823 NaN NaN        NaN
# 3228 NaN NaN        NaN
# 3390 NaN NaN        NaN
# 3700 NaN NaN        NaN
# 3701 NaN NaN        NaN
# 3951 NaN NaN        NaN
# 3977 NaN NaN        NaN
# 4050 NaN NaN        NaN
# 4394 NaN NaN        NaN
# 4953 NaN NaN        NaN
# 5036 NaN NaN        NaN
# 5085 NaN NaN        NaN
# 5283 NaN NaN        NaN
# 5780 NaN NaN        NaN
# 5913 NaN NaN        NaN
#
# [32 rows x 28 columns]

# %%
data[data["x"].isna() | data["y"].isna()][["full_address", "parcel"]]
# Out:
#                                     full_address        parcel
# 15                        Maverick 233 Boston MA  01-05327-000
# 1965                      Hanson ST 38 Boston MA  03-05900-008
# 2264                   Chandler ST 108 Boston MA  04-00050-004
# 2384         1  DALTON ST # 4303 BOSTON MA 02115  04-01149-240
# 2438                     Holyoke ST 24 Boston MA  04-00741-006
# 2439                     Holyoke ST 24 Boston MA  04-00741-008
# 2471                  St Botolph ST 41 Boston MA  04-01007-006
# 2601                     BEACON ST 146 Boston MA  05-02588-008
# 2766  160  COMMONWEALTH AV # 521 BOSTON MA 02116  05-01383-214
# 2803               COMMONWEALTH AV 315 Boston MA  05-03577-002
# 2804               COMMONWEALTH AV 315 Boston MA  05-03577-004
# 2805               COMMONWEALTH AV 315 Boston MA  05-03577-006
# 2806               COMMONWEALTH AV 315 Boston MA  05-03577-008
# 2807               COMMONWEALTH AV 315 Boston MA  05-03577-010
# 2808               COMMONWEALTH AV 315 Boston MA  05-03577-012
# 2809               COMMONWEALTH AV 315 Boston MA  05-03577-014
# 2815               COMMONWEALTH AV 341 Boston MA  05-03588-012
# 2823               COMMONWEALTH AV 377 Boston MA  05-03820-004
# 3228      616  E FOURTH ST # 102 BOSTON MA 02127  06-02076-014
# 3390     133  SEAPORT BLVD # 708 BOSTON MA 02210  06-02642-130
# 3700                          O ST 169 Boston MA  07-02690-002
# 3701                          O ST 169 Boston MA  07-02690-004
# 3951                Washington ST 2597 Boston MA  09-03742-202
# 3977                    CALUMET ST 148 Boston MA  10-01167-002
# 4050         87  ATHERTON ST # 2 BOSTON MA 02130  11-01215-004
# 4394          408  SEAVER ST # 3 BOSTON MA 02121  14-00992-006
# 4953        29  GOLDSMITH ST # 2 BOSTON MA 02130  19-01427-004
# 5036                      PRINCE ST 48 Boston MA  19-01610-002
# 5085        21  WACHUSETT ST # 3 BOSTON MA 02130  19-04694-006
# 5283     5259  WASHINGTON ST # 3 BOSTON MA 02132  20-10800-006
# 5780                          PLAIN 12 Boston MA  16-03581-000
# 5913                       LAGRANGE 84 Boston MA  20-02618-000

# %%
from geocode_data import geocode_address

parcels_with_no_x_y = data[data["x"].isna() | data["y"].isna()]
# print(parcels_with_no_x_y["parcel"].values)

for parcel in parcels_with_no_x_y["parcel"].values:
    # update the dataframe
    print(f"Geocoding parcel {parcel}")
    x, y = geocode_address(data[data["parcel"] == parcel]["full_address"].values[0])
    data.loc[data["parcel"] == parcel, "x"] = x
    data.loc[data["parcel"] == parcel, "y"] = y
# Out:
# Geocoding parcel 02-02084-004
# Geocoding parcel 03-06918-004
# Geocoding parcel 05-03703-010
# Geocoding parcel 05-02439-008
# Geocoding parcel 06-01548-002
# Geocoding parcel 06-00984-004
# Geocoding parcel 06-03116-002
# Geocoding parcel 07-00641-002
# Geocoding parcel 17-04031-078
# Geocoding parcel 21-00056-080
# Geocoding parcel 01-00032-000
# Geocoding parcel 16-03581-000

# %%
data[data["x"].isna() | data["y"].isna()]
# Out:
# Empty DataFrame
# Columns: [unit, street_name, sale_date, parcel, category, sale_price, street_no, price_per_sf, living_area, total_room_num, bedrooms, bathrooms, half_bathrooms, kitchens, fireplaces, ac_type, heat_type, interior_condition, parking_spots, year_built, exterior_condition, foundation, full_address, owner_name, owner_property_count, x, y, properties]
# Index: []
#
# [0 rows x 28 columns]

# %%
# save the dataframe
data.to_csv(f"{data_folder}/{file_name}", index=False)
