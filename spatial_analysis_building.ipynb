# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data_21 = pd.read_csv("data/parcels_21.csv")
data_24 = pd.read_csv("data/parcels_24.csv")
# Out:
# /var/folders/wy/50c5sv7n4wsfhhww_wwjz2tr0000gn/T/ipykernel_39677/3517134994.py:1: DtypeWarning: Columns (65) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_21 = pd.read_csv("data/parcels_21.csv")
# /var/folders/wy/50c5sv7n4wsfhhww_wwjz2tr0000gn/T/ipykernel_39677/3517134994.py:2: DtypeWarning: Columns (20,65) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_24 = pd.read_csv("data/parcels_24.csv")

# %%
data_21.describe()
# Out:
#                 PID         CM_ID        GIS_ID      UNIT_NUM        ZIPCODE  \
# count  1.532590e+05  7.749400e+04  1.532590e+05  4.736200e+04  153259.000000
# mean   1.183899e+09  9.543166e+08  1.183900e+09  8.767359e+03    2130.125298
# std    7.078054e+08  6.974309e+08  7.078063e+08  1.858242e+06      31.917560
# min    1.000010e+08  1.000190e+08  1.000010e+08  0.000000e+00    2026.000000
# 25%    5.025981e+08  4.008410e+08  5.025980e+08  2.000000e+00    2120.000000
# 50%    1.300151e+09  6.030820e+08  1.300151e+09  4.000000e+00    2127.000000
# 75%    1.812670e+09  1.700924e+09  1.812670e+09  1.250000e+02    2131.000000
# max    2.205668e+09  2.205665e+09  2.205668e+09  4.044054e+08    2467.000000
#
#             BLDG_SEQ      NUM_BLDGS          PTYPE      RES_FLOOR  \
# count  153209.000000  153209.000000  153259.000000  146118.000000
# mean        1.001214       1.010371     160.482778       1.926132
# std         0.037179       0.233098     220.872197       1.252354
# min         1.000000       1.000000      13.000000       1.000000
# 25%         1.000000       1.000000     102.000000       1.000000
# 50%         1.000000       1.000000     102.000000       2.000000
# 75%         1.000000       1.000000     104.000000       2.500000
# max         4.000000      47.000000     995.000000      62.000000
#
#            CD_FLOOR  ...  NEAR_FID_sports  NEAR_DIST_sports  NEAR_FID_subway  \
# count  59620.000000  ...    153259.000000     153259.000000    153259.000000
# mean       3.923834  ...       173.256200       4738.812328        11.691020
# std        5.389555  ...        33.763104       3085.808950         6.267789
# min        1.000000  ...        38.000000        311.107569         1.000000
# 25%        2.000000  ...       158.000000       2044.109427         6.000000
# 50%        3.000000  ...       169.000000       4156.300453        11.000000
# 75%        4.000000  ...       189.000000       7457.308572        17.000000
# max       60.000000  ...       262.000000      13656.370762        23.000000
#
#        NEAR_DIST_subway  NEAR_tree_cnt  NEAR_DIST_university  \
# count     153259.000000  152902.000000         153259.000000
# mean        1206.715141      58.357759           1653.185784
# std          789.432793      66.887922           1124.764924
# min            0.000000       1.000000              1.349142
# 25%          665.311115      26.000000            587.581092
# 50%          995.981892      44.000000           1636.843977
# 75%         1606.132696      70.000000           2432.072513
# max         7129.865736    1603.000000           6982.951824
#
#        NEAR_FID_university           LAT           LONG   NEAR_BUS_cnt
# count        153259.000000  1.532590e+05  153259.000000  153259.000000
# mean             23.903940  2.943105e+06  767156.573332       4.651844
# std              11.715201  1.283128e+04   10584.535850       3.340180
# min               1.000000  2.909812e+06  744103.861021       0.000000
# 25%              17.000000  2.931423e+06  758933.686068       2.000000
# 50%              24.000000  2.946328e+06  769850.895744       4.000000
# 75%              34.000000  2.953012e+06  775133.804839       7.000000
# max              43.000000  2.968499e+06  799998.265513      18.000000
#
# [8 rows x 68 columns]

# %%
print(data_21["BLDG_VALUE"].isna().sum()) 
print(data_24["BLDG_VALUE"].isna().sum())
# Out:
# 15707
# 0

# %%
data_21["PID"] = data_21["PID"].astype(int)
data_24["PID"] = data_24["PID"].astype(int)

# %%
# data_21.columns

for col in data_21.columns:
    print(col)
# Out:
# PID
# CM_ID
# GIS_ID
# ST_NUM
# ST_NAME
# UNIT_NUM
# CITY
# ZIPCODE
# BLDG_SEQ
# NUM_BLDGS
# PTYPE
# LU
# PTYPE_DESC
# BLDG_TYPE
# OWN_OCC
# OWNER
# MAIL_ADDRESSEE
# MAIL_ADDRESS
# MAIL_CITY
# MAIL_STATE
# MAIL_ZIPCODE
# RES_FLOOR
# CD_FLOOR
# RES_UNITS
# COM_UNITS
# LAND_SF
# GROSS_AREA
# LIVING_AREA
# LAND_VALUE
# BLDG_VALUE
# TOTAL_VALUE
# GROSS_TAX
# YR_BUILT
# YR_REMODEL
# STRUCTURE_CLASS
# ROOF_STRUCTURE
# ROOF_COVER
# INT_WALL
# EXT_FINISHED
# INT_COND
# EXT_COND
# OVERALL_COND
# BED_RMS
# FULL_BTH
# HLF_BTH
# KITCHEN
# TT_RMS
# BDRM_COND
# BTHRM_STYLE1
# BTHRM_STYLE2
# BTHRM_STYLE3
# KITCHEN_TYPE
# KITCHEN_STYLE1
# KITCHEN_STYLE2
# KITCHEN_STYLE3
# HEAT_TYPE
# HEAT_FUEL
# AC_TYPE
# FIRE_PLACE
# PLUMBING
# NUM_PARKING
# PROP_VIEW
# CORNER_UNIT
# parcels_21_prelim_OBJECTID
# MAP_PAR_ID
# BPDA_Name
# LU_DESC
# Address
# Shape_Length
# Shape_Area
# NEAR_FID_Community_Garden
# NEAR_DIST_Community_Garden
# NEAR_FID_Cemetries_Burying
# NEAR_DIST_Cemetries_Burying
# NEAR_FID_Parks_Playground
# NEAR_DIST_Parks_Playground
# NEAR_FID_Parkways_Beaches
# NEAR_DIST_Parkways_Beaches
# NEAR_FID_Mall_Squares
# NEAR_DIST_Mall_Squares
# NEAR_FID_Farmers_Market
# NEAR_DIST_Farmers_Market
# NEAR_FID_Music_Venue
# NEAR_DIST_Music_Venue
# NEAR_FID_Landmark
# NEAR_DIST_Landmark
# NEAR_FID_library
# NEAR_DIST_library
# RESTAURANT_CNT
# NOISE_INCIDENT_CNT
# NEAR_DIST_health
# NEAR_FID_safety
# NEAR_DIST_safety
# NEAR_School_cnt
# NEAR_DIST_security
# NEAR_FID_security
# NEAR_FID_sports
# NEAR_DIST_sports
# NEAR_FID_subway
# NEAR_DIST_subway
# NEAR_tree_cnt
# NEAR_DIST_university
# NEAR_FID_university
# LAT
# LONG
# NEAR_BUS_cnt

# %%
data_21["LU"].unique()

# drop the LU of "A"
data_21 = data_21[data_21["LU"].isin(['R1', 'R2', 'R3', 'R4', "A"])]
# data_21["LU"].unique()

# %%
data_21["BLDG_VALUE"]
# Drop rows with empty building values
data_21 = data_21.dropna(subset=['BLDG_VALUE'])

# %%
# check the bedroom nan portion
data_21["BED_RMS"].isnull().sum() / len(data_21)

# drop the bedroom nan
data_21 = data_21.dropna(subset=['BED_RMS'])

# check the bedroom nan portion
data_21["BED_RMS"].isnull().sum() / len(data_21)
# Out:
# np.float64(0.0)

# %%
# count null values
data_21["BLDG_VALUE"].isnull().sum()
# Out:
# np.int64(0)

# %%
intersecting_ids = set(data_21["PID"]) & set(data_24["PID"])

print(data_21["PID"].nunique())
print(data_24["PID"].nunique())
print(len(intersecting_ids))
# Out:
# 61355
# 144021
# 58666

# %%
# we will get the bld_value of the 2024 data and add column to the data
# First filter data_24 to get matching PIDs, then map values using PID as key
data = data_21[data_21["PID"].isin(intersecting_ids)].copy()  # Use copy() to avoid SettingWithCopyWarning

# Create a mapping dictionary from data_24
value_map = data_24[data_24["PID"].isin(intersecting_ids)].set_index("PID")["TOTAL_VALUE"].to_dict()


inflation_2021 = 0.0470  # 4.70%
inflation_2022 = 0.0800  # 8.00%
inflation_2023 = 0.0412  # 4.12%



# Map the values using the dictionary
data["BLDG_VALUE_2024"] = data["PID"].map(value_map)

# %%
# drop bldg value that are 0
data = data[data["BLDG_VALUE"] != 0]
data = data[data["BLDG_VALUE_2024"] != 0]

# %%
cumulative_inflation = (1 + inflation_2021) * (1 + inflation_2022) * (1 + inflation_2023)

data["BLDG_VALUE_2024_2021_DOLLARS"] = data["BLDG_VALUE_2024"] / cumulative_inflation

data["NOMINAL_INCREASE"] = data["BLDG_VALUE_2024"] - data["BLDG_VALUE"] 
data["REAL_INCREASE"] = data["BLDG_VALUE_2024_2021_DOLLARS"] - data["BLDG_VALUE"]

data["NOMINAL_INCREASE_PERCENT"] = (data["NOMINAL_INCREASE"] / data["BLDG_VALUE"]) * 100
data["REAL_INCREASE_PERCENT"] = (data["REAL_INCREASE"] / data["BLDG_VALUE"]) * 100

print(f"Cumulative inflation 2021-2024: {(cumulative_inflation - 1) * 100:.2f}%")
print("\nValue Change Summary:")
summary = data[["NOMINAL_INCREASE_PERCENT", "REAL_INCREASE_PERCENT"]].describe()
print(summary)
# Out:
# Cumulative inflation 2021-2024: 17.73%
#
# Value Change Summary:
#        NOMINAL_INCREASE_PERCENT  REAL_INCREASE_PERCENT
# count              58138.000000           58138.000000
# mean                  79.244910              52.244718
# std                   57.478689              48.820504
# min                  -74.321881             -78.189852
# 25%                   59.736536              35.674948
# 50%                   74.376371              48.109542
# 75%                   93.152101              64.057028
# max                 5880.000000            4979.214892

# %%
# Filter for properties with positive real value increases
positive_real_increases = data[data["REAL_INCREASE"] >= 0]

print("\nProperties with Real Value Increases:")
print(f"Count: {len(positive_real_increases)} ({(len(positive_real_increases)/len(data))*100:.1f}% of properties)")
print("\nSummary of Real Increases for Properties with Gains:")
print(positive_real_increases["REAL_INCREASE_PERCENT"].describe())
# Out:
# Properties with Real Value Increases:
# Count: 57152 (98.3% of properties)
#
# Summary of Real Increases for Properties with Gains:
# count    57152.000000
# mean        53.228906
# std         48.641514
# min          0.064692
# 25%         36.306457
# 50%         48.544195
# 75%         64.374747
# max       4979.214892
# Name: REAL_INCREASE_PERCENT, dtype: float64

# %%
print(data["BLDG_VALUE"].isna().sum())
# Out:
# 0

# %%
# count null building values
print(data["BLDG_VALUE"].isna().sum())  
print(data["BLDG_VALUE_2024"].isna().sum())
# Out:
# 0
# 0

# %%
negative_real_increases = data[data["REAL_INCREASE"] < 0]

print("\nProperties with Real Value Increases:")
print(f"Count: {len(negative_real_increases)} ({(len(negative_real_increases)/len(data))*100:.1f}% of properties)")
print("\nSummary of Real Increases for Properties with Gains:")
print(negative_real_increases["REAL_INCREASE_PERCENT"].describe())
# Out:
# Properties with Real Value Increases:
# Count: 986 (1.7% of properties)
#
# Summary of Real Increases for Properties with Gains:
# count    986.000000
# mean      -4.802251
# std        9.174090
# min      -78.189852
# 25%       -1.702263
# 50%       -1.682014
# 75%       -1.667651
# max       -0.430534
# Name: REAL_INCREASE_PERCENT, dtype: float64

# %%
# sort the negative real increases by the absolute value of the real increase
negative_real_increases = negative_real_increases.sort_values(by="REAL_INCREASE_PERCENT", ascending=True)
# print the top 10
negative_real_increases[["BLDG_VALUE", "BLDG_VALUE_2024", "REAL_INCREASE", "REAL_INCREASE_PERCENT", "PID", "LU"]].head(10)
# print the bottom 10
# print(negative_real_increases.tail(10))
# Out:
#        BLDG_VALUE  BLDG_VALUE_2024  REAL_INCREASE  REAL_INCREASE_PERCENT  \
# 94705   1106000.0         284000.0 -864779.760989             -78.189852
# 84364    879200.0         231524.0 -682551.145715             -77.633206
# 7740     694600.0         231969.0 -497573.177383             -71.634491
# 80173    695700.0         328700.0 -416513.054356             -59.869636
# 83739    808600.0         390207.0 -477171.035902             -59.012000
# 7397     381100.0         210328.0 -202454.329469             -53.123676
# 94704    522200.0         292500.0 -273760.141159             -52.424386
# 94673    517900.0         292500.0 -269460.141159             -52.029377
# 81613    227500.0         129600.0 -117422.031775             -51.614080
# 5651     751900.0         429800.0 -386842.046736             -51.448603
#
#               PID  LU
# 94705  1701569000  R3
# 84364  1501266000  R3
# 7740    106807020  R3
# 80173  1402103000  R3
# 83739  1500606001  R3
# 7397    106503000  R3
# 94704  1701568000  R2
# 94673  1701535000  R2
# 81613  1403685000  R1
# 5651    104918000  R3

# %%
# save the data
data.to_csv("data/parcels_intersecting.csv", index=False)

# %%
# Cehck any null among x_columns
X_columns = ["BED_RMS", "NEAR_BUS_cnt", "NEAR_DIST_Farmers_Market", "NEAR_DIST_Music_Venue",
          "NEAR_DIST_health", "LAT", "LONG", \
          "NEAR_DIST_Community_Garden", "NEAR_DIST_Cemetries_Burying", \
        "NEAR_DIST_Parks_Playground", "NEAR_DIST_Parkways_Beaches", \
        "NEAR_DIST_Mall_Squares",  "NEAR_DIST_Landmark", "RESTAURANT_CNT", \
        "NEAR_DIST_library", "LIVING_AREA",\
        "NEAR_DIST_safety", "NEAR_School_cnt", "NEAR_DIST_security", "NEAR_DIST_sports", "NEAR_DIST_subway", \
        "NEAR_tree_cnt", "NEAR_DIST_university"]

# Remove Living Area NaN values
data = data[data["LIVING_AREA"].notna()]

X_columns_null = [col for col in X_columns if data[col].isnull().any()]
print(X_columns_null)

# fill in the null values with 0
data[X_columns_null] = data[X_columns_null].fillna(0)
# Out:
# ['RESTAURANT_CNT', 'NEAR_tree_cnt']

# %%
from xgboost import XGBRegressor
from sklearn.model_selection import cross_val_score, KFold

# create a model to predict the real increase percent
Y = data["REAL_INCREASE_PERCENT"]
X = data[["BED_RMS", "NEAR_BUS_cnt", "NEAR_DIST_Farmers_Market", "NEAR_DIST_Music_Venue",
          "NEAR_DIST_health", "LAT", "LONG", \
          "NEAR_DIST_Community_Garden", "NEAR_DIST_Cemetries_Burying", \
        "NEAR_DIST_Parks_Playground", "NEAR_DIST_Parkways_Beaches", \
        "NEAR_DIST_Mall_Squares",  "NEAR_DIST_Landmark", "RESTAURANT_CNT", \
        "NEAR_DIST_library", "LIVING_AREA",\
        "NEAR_DIST_safety", "NEAR_School_cnt", "NEAR_DIST_security", "NEAR_DIST_sports", "NEAR_DIST_subway", \
        "NEAR_tree_cnt", "NEAR_DIST_university"]]

# Initialize model with same parameters
model = XGBRegressor(max_depth=11, n_estimators=2031, learning_rate=0.013,\
    subsample=0.72, colsample_bytree=0.6, gamma=0.1, reg_lambda=1.95, reg_alpha=2.1,
    min_child_weight=11)

model = XGBRegressor()


# Perform 5-fold cross validation
kf = KFold(n_splits=5, shuffle=True, random_state=42)
cv_scores = cross_val_score(model, X, Y, cv=kf, scoring='r2')

# Print cross validation results
print("Cross Validation Scores:")
for i, score in enumerate(cv_scores, 1):
    print(f"Fold {i}: {score:.4f}")
print(f"\nMean CV Score: {cv_scores.mean():.4f}")
print(f"Standard Deviation: {cv_scores.std():.4f}")

# Fit the model on the full dataset to get feature importances
model.fit(X, Y)

# Print feature importances
print("\nFeature importances:")
print(model.feature_importances_)
# Out:
# Cross Validation Scores:
# Fold 1: 0.0875
# Fold 2: 0.0411
# Fold 3: -0.0833
# Fold 4: 0.0163
# Fold 5: 0.0959
#
# Mean CV Score: 0.0315
# Standard Deviation: 0.0645
#
# Feature importances:
# [0.07119741 0.0943269  0.03074276 0.14428428 0.02136041 0.09299766
#  0.02991245 0.013574   0.06119523 0.025468   0.01753331 0.03851097
#  0.04857185 0.03556485 0.05403644 0.04387115 0.0527513  0.04785005
#  0.00797076 0.01207567 0.01617069 0.02811365 0.0119203 ]

# %%
# Get feature importances from XGBoost model
importances = model.feature_importances_

# Create dictionary mapping features to their importance scores
importance_dict = dict(zip(X.columns, importances))

# Print feature importances in order
print("Feature Importances:")
for feature, importance in sorted(importance_dict.items(), key=lambda x: x[1], reverse=True):
    print(f"{feature}: {importance:.4f}")
# Out:
# Feature Importances:
# NEAR_DIST_Music_Venue: 0.1443
# NEAR_BUS_cnt: 0.0943
# LAT: 0.0930
# BED_RMS: 0.0712
# NEAR_DIST_Cemetries_Burying: 0.0612
# NEAR_DIST_library: 0.0540
# NEAR_DIST_safety: 0.0528
# NEAR_DIST_Landmark: 0.0486
# NEAR_School_cnt: 0.0479
# LIVING_AREA: 0.0439
# NEAR_DIST_Mall_Squares: 0.0385
# RESTAURANT_CNT: 0.0356
# NEAR_DIST_Farmers_Market: 0.0307
# LONG: 0.0299
# NEAR_tree_cnt: 0.0281
# NEAR_DIST_Parks_Playground: 0.0255
# NEAR_DIST_health: 0.0214
# NEAR_DIST_Parkways_Beaches: 0.0175
# NEAR_DIST_subway: 0.0162
# NEAR_DIST_Community_Garden: 0.0136
# NEAR_DIST_sports: 0.0121
# NEAR_DIST_university: 0.0119
# NEAR_DIST_security: 0.0080

# %%
import shap
import matplotlib.pyplot as plt

# Create a SHAP explainer
explainer = shap.Explainer(model, X)

# Calculate SHAP values
shap_values = explainer(X)

# Create SHAP summary plot
shap.summary_plot(shap_values, X)  # You can use "bar" for bar plot
# Out:
#  99%|===================| 57667/58136 [01:22<00:00]

# %%
# plot a bar chart of the feature importances

shap.summary_plot(shap_values, X, plot_type="bar")
