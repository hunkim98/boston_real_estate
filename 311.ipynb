# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data_311_2021 = pd.read_csv("data/2021_311.csv")
data_311_2022 = pd.read_csv("data/2022_311.csv")
data_311_2023 = pd.read_csv("data/2023_311.csv")
data_311_2024 = pd.read_csv("data/2024_311.csv")

data_311_2021.head()
# Out:
# /var/folders/wy/50c5sv7n4wsfhhww_wwjz2tr0000gn/T/ipykernel_27816/2349612621.py:1: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_311_2021 = pd.read_csv("data/2021_311.csv")
# /var/folders/wy/50c5sv7n4wsfhhww_wwjz2tr0000gn/T/ipykernel_27816/2349612621.py:2: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_311_2022 = pd.read_csv("data/2022_311.csv")
# /var/folders/wy/50c5sv7n4wsfhhww_wwjz2tr0000gn/T/ipykernel_27816/2349612621.py:3: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_311_2023 = pd.read_csv("data/2023_311.csv")
#    case_enquiry_id              open_dt        sla_target_dt  \
# 0     101003578903  2021-01-01 00:35:24  2021-01-05 03:30:00
# 1     101003578905  2021-01-01 00:39:00                  NaN
# 2     101003578906  2021-01-01 00:42:00  2021-01-05 03:30:00
# ...

# %%
merged_data = pd.concat([data_311_2021, data_311_2022, data_311_2023, data_311_2024])

merged_data.head()

merged_data.to_csv("data/merged_311.csv", index=False)

# %%
# check any missing values
merged_data.isnull().sum()

# check the distribution of the data
merged_data.describe()
# Out:
#        case_enquiry_id  location_zipcode      latitude     longitude
# count     1.099657e+06     859545.000000  1.091777e+06  1.091777e+06
# mean      1.010047e+11       2127.028648  4.232928e+01 -7.108180e+01
# std       6.576651e+05         18.410786  3.253663e-02  3.520098e-02
# min       1.010036e+11       2108.000000  4.223024e+01 -7.119066e+01
# 25%       1.010041e+11       2119.000000  4.230642e+01 -7.110283e+01
# 50%       1.010046e+11       2126.000000  4.233581e+01 -7.107430e+01
# 75%       1.010052e+11       2130.000000  4.235184e+01 -7.105772e+01
# max       1.010059e+11       2467.000000  4.239899e+01 -7.095756e+01

# %%
# columns
merged_data.columns
# Out:
# Index(['case_enquiry_id', 'open_dt', 'sla_target_dt', 'closed_dt', 'on_time',
#        'case_status', 'closure_reason', 'case_title', 'subject', 'reason',
#        'type', 'queue', 'department', 'submitted_photo', 'closed_photo',
#        'location', 'fire_district', 'pwd_district', 'city_council_district',
#        'police_district', 'neighborhood', 'neighborhood_services_district',
#        'ward', 'precinct', 'location_street_name', 'location_zipcode',
#        'latitude', 'longitude', 'geom_4326', 'source'],
#       dtype='object')

# %%
# check types
merged_data["type"]

# check the number of unique values
print(len(merged_data["type"].unique()))

# group by type
# merged_data.groupby("reason").size()

# sort by count
print(merged_data.groupby("reason").size().sort_values(ascending=False))

# check the number of missing values
# merged_data["type"].isnull().sum()
# Out:
# 187
# reason
# Enforcement & Abandoned Vehicles     254795
# Street Cleaning                      173698
# Code Enforcement                     124061
# Highway Maintenance                   96574
# Sanitation                            84195
# Signs & Signals                       44267
# Trees                                 40542
# Recycling                             40317
# Needle Program                        32863
# Street Lights                         32444
# Park Maintenance & Safety             31618
# Housing                               28533
# Building                              25694
# Environmental Services                18884
# Animal Issues                         16462
# Graffiti                              12435
# Employee & General Comments            8187
# Administrative & General Requests      8010
# Health                                 5564
# Abandoned Bicycle                      4252
# Noise Disturbance                      2843
# ...
